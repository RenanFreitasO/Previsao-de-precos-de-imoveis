# %% [markdown]
# ### Imports

# %%
import pandas as pd
from sklearn import linear_model as lm
import numpy as np

# %% [markdown]
# ### Loading data

# %%
dados_brutos = pd.read_csv(r"C:\Users\Renan\Desktop\kc_house_data.csv")
dados_brutos
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
variaveis_de_interesse = dados_brutos[[ 'price','sqft_lot', 'sqft_living', 'sqft_above', 'sqft_basement']]

# %%
X = variaveis_de_interesse[['sqft_lot', 'sqft_living', 'sqft_above', 'sqft_basement']]
y = variaveis_de_interesse['price']
x_train = variaveis_de_interesse.iloc[:, 2].values
y_train = variaveis_de_interesse.iloc[:, 0].values

model_lr = lm.LinearRegression()

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
teste_previsao = variaveis_de_interesse.sample(frac=0.8, replace=False, weights=None, axis=0)

from sklearn.linear_model import LinearRegression

regressor = LinearRegression()

regressor.fit(X_train, y_train)

df_coef = pd.DataFrame(regressor.coef_, X.columns, columns=['Coeficiente'])

y_pred = regressor.predict(X_test)

teste_previsao = pd.DataFrame({'teste': y_test, 'Previsão': y_pred})

# %%
df_treino = variaveis_de_interesse.sample(frac=0.8, replace=False, weights=None, axis=0)

df_treino
# Out:
#           price  sqft_lot  sqft_living  sqft_above  sqft_basement
# 6993   325000.0      7205         2000        2000              0
# 7430   583000.0      4011         1840        1840              0
# 14303  397000.0      8584         3000        3000              0
# 7193   630000.0      1502         1910        1910              0
# 9311   235000.0      8362         1380        1380              0
# ...         ...       ...          ...         ...            ...
# 20481  416000.0      6322         2890        2890              0
# 4615   407500.0      6017          770         770              0
# 4434   610000.0      5827         2630        2630              0
# 1225   365000.0      9600         1570         800            770
# 5071   625000.0     10092         2600        2600              0
#
# [17290 rows x 5 columns]

# %%
X = df_treino[['sqft_lot', 'sqft_living', 'sqft_above', 'sqft_basement']]
y = df_treino['price']

model_lr = lm.LinearRegression()

regressor = LinearRegression()

regressor.fit(X, y)

df_coef = pd.DataFrame(regressor.coef_, X.columns, columns=['Coeficiente'])

y_pred = regressor.predict(X)

previsao = pd.DataFrame({'teste': y, 'Previsão': y_pred})

previsao
# Out:
#           teste       Previsão
# 6993   325000.0  516839.133351
# 7430   583000.0  473032.582854
# 14303  397000.0  795764.735290
# 7193   630000.0  493277.288576
# 9311   235000.0  343349.345714
# ...         ...            ...
# 20481  416000.0  765666.002304
# 4615   407500.0  173620.234494
# 4434   610000.0  693183.049994
# 1225   365000.0  406589.015141
# 5071   625000.0  683625.422570
#
# [17290 rows x 2 columns]

# %%
dados_e_previsao = df_treino.copy()

dados_e_previsao['previsão de preço'] = y_pred

dados_e_previsao
# Out:
#           price  sqft_lot  sqft_living  sqft_above  sqft_basement  \
# 6993   325000.0      7205         2000        2000              0
# 7430   583000.0      4011         1840        1840              0
# 14303  397000.0      8584         3000        3000              0
# 7193   630000.0      1502         1910        1910              0
# 9311   235000.0      8362         1380        1380              0
# ...         ...       ...          ...         ...            ...
# 20481  416000.0      6322         2890        2890              0
# 4615   407500.0      6017          770         770              0
# 4434   610000.0      5827         2630        2630              0
# 1225   365000.0      9600         1570         800            770
# 5071   625000.0     10092         2600        2600              0
#
#        previsão de preço
# 6993       516839.133351
# 7430       473032.582854
# 14303      795764.735290
# 7193       493277.288576
# 9311       343349.345714
# ...

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y, y_pred)))
# Out:
# Mean Absolute Error: 173987.2455213593
# Mean Squared Error: 68140144519.96046
# Root Mean Squared Error: 261036.6727491761
